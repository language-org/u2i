# %% [markdown]
# # INTENT PARSING

# %% [markdown]
# * **Purpose** :
#   * Test intent parsing with ALLENLP

# %% [markdown]
#  * TABLE OF CONTENT
#  * SETUP
#    * paths
#  * PARAMETERS
#  * PARSING
#    * Allennlp VP parsing
#    * Parsing performance
#    * Focus on the class well parsed
#  * ANNOTATION
#    * Annotate well-formed intent VPs vs. not
#  * CFG FEATURES
#
#  To read
#  * Berkeley Neural Parser w/ spacy:
#    https://spacy.io/universe/project/self-attentive-parser
#    https://www.analyticsvidhya.com/blog/2020/07/part-of-speechpos-tagging-dependency-parsing-and-constituency-parsing-in-nlp/

# %% [markdown]
# # SETUP

# %%
import os
from datetime import datetime
from time import time

import numpy as np
import pandas as pd
import yaml
from nltk.tree import ParentedTree
from pigeon import annotate

proj_path = "/Users/steeve_laquitaine/desktop/CodeHub/intent/"
os.chdir(proj_path)
# in root
from intent.src.intent.nodes import annotation, mood, parsing, preprocess
from intent.src.tests import test_run

# dataframe display
pd.set_option("display.max_colwidth", 100)
pd.set_option("display.max_rows", 1000)

# pd.set_option('display.notebook_repr_html', True)

# to display df w/ nbconvert to pdf
# def _repr_latex_(self):
    # return "\centering{%s}" % self.to_latex()
# pd.DataFrame._repr_latex_ = _repr_latex_  # monkey patch pandas DataFrame

# %% [markdown]
# ## paths

# %%
# load catalog
with open(proj_path+"intent/conf/base/catalog.yml") as file:
    catalog = yaml.load(file)
with open(proj_path+"intent/conf/base/parameters.yml") as file:
    prms = yaml.load(file)
tr_data_path = proj_path + "intent/data/01_raw/banking77/train.csv"
test_data_path = proj_path + "intent/data/01_raw/banking77/test.csv"

# %%
# read queries data
tr_data = pd.read_csv(tr_data_path)

# %%
sample = preprocess.sample(tr_data)

# %%
sample.head(5)
# Out:
#    index                                            text      category
# 0     26            How do I track the card you sent me?  card_arrival
# 1    135             I was expecting my new card by now.  card_arrival
# 2     63            Can I track the card you sent to me?  card_arrival
# 3    105  What is the expected delivery date of my card?  card_arrival
# 4     24                           where is my new card?  card_arrival

# %% [markdown]
# # PARSING

# %% [markdown]
# ## ALLENLP VP PARSING

# %%
al_prdctor = parsing.init_allen_parser()
# Out:
# (Instantiation) took 33.68 secs

# %%
tic = time()
out = al_prdctor.predict(sentence=sample['text'].iloc[0])
parsed_txt = out["trees"]
print(f"(Inference) took {round(time()-tic,2)} secs")
print(f"Parsed sample:\n{parsed_txt}")
# Out:
# Your label namespace was 'pos'. We recommend you use a namespace ending with 'labels' or 'tags', so we don't add UNK and PAD tokens by default to your vocabulary.  See documentation for `non_padded_namespaces` parameter in Vocabulary.
# (Inference) took 0.36 secs
# Parsed sample:
# (SBARQ (WHADVP (WRB How)) (SQ (VBP do) (NP (PRP I)) (VP (VB track) (NP (NP (DT the) (NN card)) (SBAR (S (NP (PRP you)) (VP (VBD sent) (NP (PRP me)))))))) (. ?))

# %%
tree = ParentedTree.fromstring(parsed_txt)
test_run.test_extract_VP(al_prdctor)

# %%
# Speed up (1 hour / 10K queries)
VP_info = parsing.extract_all_VPs(sample, al_prdctor)
test_run.test_extract_all_VPs(VP_info, sample, prms)
# Out:
# Time to completion: 34.08
# Time to completion: 34.18
# Time to completion: 32.7
# Time to completion: 31.84
# Time to completion: 29.47
# Time to completion: 31.35
# Time to completion: 32.14
# Time to completion: 34.58
# Time to completion: 33.97
# Time to completion: 34.18
# Time to completion: 34.34
# 33.56

# %%
VPs = parsing.make_VPs_readable(VP_info)

# %%
VP_info = parsing.get_CFGs(VP_info)

# %%
sample["VP"] = np.asarray(VPs)
sample["cfg"] = np.asarray([VP['cfg'] if not len(VP)==0 else None for VP in VP_info])

# %% [markdown]
#  Write parsed data

# %%
sample.to_excel(catalog['parsed'])

# %%
# verb_p[0].pretty_print()

# %% [markdown]
# ## PARSING PERFORMANCE
#
#  * **Parser works in 62% of the cases for "card_arrival" and never for other classes**
#
#    * see 2a_eda_parsing.py
#    * We will analyse why later.
#    * We now focus on the class well parsed: "card_arrival".

# %% [markdown]
# ## FOCUS ON THE CLASS WELL PARSED
#
#  moods = mood.classify_mood(data["text"])
#  moods
#
# ### ANNOTATE
#
#  1. Annotate well-formed intent VPs vs. not

# %%
# can't be made into a function because of Pigeon "annotate"
if prms['annotation'] == 'do':
    annots = annotate(sample["VP"], options=["yes", "no"])
else:
    annots, myfile, myext = annotation.get_annotation(catalog, prms, sample)

# %%
annots_df = annotation.index_annots(prms, sample, annots)

# %%
annotation.write_annotation(catalog, prms, annots_df, myfile, myext)
# Out:
# WARNING: Annots was not written. To write, delete existing and rerun.
#     index                                                                VP  \
# 0      26                                        track the card you sent me
# 1     135                                  was expecting my new card by now
# 2      63                                     track the card you sent to me
# 3     105                          is the expected delivery date of my card
# 4      24                                                    is my new card
# 5       7                       do if I still have not received my new card
# 6      44                       tell me why I have n't received my new card
# 7     101                                         have not received my card
# 8     112                             have n't received my card in the mail
# 9      54                           check the delivery of the card you sent
# 10     86                                          have n't received it yet
# 11     94                                          get tracking on the card
# 12     83                           track the card that was just sent to me
# 13    139                       tell me if I can track the card you sent me
# 14    104                                          received my new card yet
# 15     40                 need to find out where the card is that I ordered
# 16     33                                                   has n't came in
# 17    111               tell me where my card is ? I ordered it 2 weeks ago
# 18     69                           check on the delivery status of my card
# 19    119                                       take to recieve my new card
# 20     56                                    take for me to get my new card
# 21      8                                                     have tracking
# 22    136                               is the tracking number for the card
# 23     80                                               has n't arrived yet
# 24     37                              's the tracking on the card you sent
# 25     98          would like to track a card sent to me , how do I do that
# 26    137                                  was issued a new card a week ago
# 27     60                                          to get tracking for that
# 28     91                                      'm still waiting for my card
# 29     51                                         can get my card expedited
# 30     16               do n't have my card in 1 week . Should I be worried
# 31    126                                                   get my new card
# 32    102                              can check on the card on route to me
# 33     92  need to do to get my new card which I have requested 2 weeks ago
# 34     22                                              sent out my card yet
# 35     66                have to wait much longer for my new card to arrive
# 36     97                                                   has n't arrived
# 37    138                       track the card that you sent me in the mail
# 38     27                                               recieve my new card
# 39    149                                               has n't arrived yet
# 40    151                                     appears to have never arrived
# 41     45                                  'm still waiting for my new card
# 42     18          has not been delivered to my home yet . What is going on
# 43     59                     want to find out what happened to my new card
# 44     30                                                           sent me
# 45    150                        has n't arrived after two weeks , now what
# 46     73                                            was supposed to arrive
# 47      2          have been waiting over a week . Is the card still coming
# 48    134                   's been two weeks and I have n't gotten my card
# 49     43                        to track the card that was just sent to me
# 50     10                                                              come
# 51     96                                                    be here by now
# 52    121                                        sent me 's tracking number
# 53    147                                  going to take to get my new card
# 54    124           thought I would have received my new card at this point
# 55     61                                      am still waiting for my card
# 56     71                  's the expected wait time to recieve my new card
# 57     85                                                          's go on
# 58     62                                                   has n't arrived
# 59     78                                   has n't arrived in the mail yet
# 60    128                                     to track the card you sent me
# 61    144                                                     was just sent
# 62    110                                was issued a card about a week ago
# 63    107                                         have n't received my card
# 64     50                                               has been sent to me
# 65     89                                                  to track my card
# 66     64                                       have n't gotten my new card
# 67     93                                   IS THE SOLUTION OF THIS PROBLEM
# 68     95                                             help me track my card
# 69     49                                check on the status of my new card
# 70     48                              track when my card will be delivered
# 71     13                                  to track the delivery of my card
# 72    132                                                   got my new card
# 73    129                                           be to get this new card
# 74     20                                                         is coming
# 75     15                     be able to track the card that was sent to me
# 76     52                                  do to track the card you sent me
# 77     76                                              has n't shown up yet
# 78      3              track my card while it is in the process of delivery
# 79    152                                                           arrived
# 80     90                                 to track the new card you sent me
# 81      6                              have info about the card on delivery
# 82     68                                               ordered my new card
# 83    113           'm still waiting for my card that was issued a week ago
# 84     84                                     ordered my new card last week
# 85    100                                        share card tracking number
# 86     12                                              track my card for me
# 87    106                                      has n't came in the mail yet
# 88    125                                                         gets here
# 89    108                                                 to track the card
# 90    130                                               track card you sent
# 91     46                                                              lost
# 92     11            have n't received my card after two weeks , is it lost
# 93    114                                       have n't gotten my new card
# 94    120                                      has not come in the mail yet
# 95     41                                                  was to be mailed
# 96    122                                               have nt got my card
# 97      1                 do if my card still has n't arrived after 2 weeks
# 98    118                     send me and up date on the arrival of my card
# 99    141                   'm still waiting on my new card to be delivered
#
#    annots
# 0     yes
# 1      no
# 2     yes
# 3      no
# 4      no
# 5      no
# 6     yes
# 7      no
# 8      no
# 9     yes
# 10     no
# 11    yes
# 12    yes
# 13    yes
# 14     no
# 15    yes
# 16     no
# 17    yes
# 18    yes
# 19     no
# 20     no
# 21     no
# 22     no
# 23     no
# 24     no
# 25     no
# 26     no
# 27    yes
# 28     no
# 29     no
# 30     no
# 31    yes
# 32     no
# 33     no
# 34     no
# 35     no
# 36     no
# 37    yes
# 38     no
# 39     no
# 40     no
# 41     no
# 42     no
# 43    yes
# 44     no
# 45     no
# 46     no
# 47     no
# 48     no
# 49    yes
# 50     no
# 51     no
# 52     no
# 53     no
# 54     no
# 55     no
# 56     no
# 57     no
# 58     no
# 59     no
# 60    yes
# 61     no
# 62     no
# 63     no
# 64     no
# 65    yes
# 66     no
# 67     no
# 68     no
# 69    yes
# 70    yes
# 71    yes
# 72     no
# 73     no
# 74     no
# 75    yes
# 76     no
# 77     no
# 78    yes
# 79     no
# 80    yes
# 81    yes
# 82     no
# 83     no
# 84     no
# 85    yes
# 86    yes
# 87     no
# 88     no
# 89    yes
# 90    yes
# 91     no
# 92     no
# 93     no
# 94     no
# 95     no
# 96     no
# 97     no
# 98     no
# 99     no

# %%
annots_df['annots'][annots_df['VP'].isnull()] = np.nan
annots_df['text'] = sample['text']
annots_df['cfg'] = sample['cfg']

# %%
parsing.write_cfg(annots_df)

# %% [markdown]
#  **Fig. Queries are sorted by annotation result below.**

# %%
sorted_annots = annots_df.sort_values(by='annots', ascending=False)

# %%
sorted_annots
# Out:
#     index                                                                VP  \
# 0      26                                        track the card you sent me
# 17    111               tell me where my card is ? I ordered it 2 weeks ago
# 75     15                     be able to track the card that was sent to me
# 71     13                                  to track the delivery of my card
# 78      3              track my card while it is in the process of delivery
# 70     48                              track when my card will be delivered
# 31    126                                                   get my new card
# 80     90                                 to track the new card you sent me
# 81      6                              have info about the card on delivery
# 43     59                     want to find out what happened to my new card
# 27     60                                          to get tracking for that
# 69     49                                check on the status of my new card
# 85    100                                        share card tracking number
# 86     12                                              track my card for me
# 89    108                                                 to track the card
# 18     69                           check on the delivery status of my card
# 90    130                                               track card you sent
# 65     89                                                  to track my card
# 11     94                                          get tracking on the card
# 2      63                                     track the card you sent to me
# 60    128                                     to track the card you sent me
# 6      44                       tell me why I have n't received my new card
# 9      54                           check the delivery of the card you sent
# 15     40                 need to find out where the card is that I ordered
# 37    138                       track the card that you sent me in the mail
# 12     83                           track the card that was just sent to me
# 13    139                       tell me if I can track the card you sent me
# 49     43                        to track the card that was just sent to me
# 68     95                                             help me track my card
# 67     93                                   IS THE SOLUTION OF THIS PROBLEM
# 63    107                                         have n't received my card
# 62    110                                was issued a card about a week ago
# 66     64                                       have n't gotten my new card
# 61    144                                                     was just sent
# 59     78                                   has n't arrived in the mail yet
# 72    132                                                   got my new card
# 73    129                                           be to get this new card
# 64     50                                               has been sent to me
# 82     68                                               ordered my new card
# 74     20                                                         is coming
# 76     52                                  do to track the card you sent me
# 98    118                     send me and up date on the arrival of my card
# 97      1                 do if my card still has n't arrived after 2 weeks
# 96    122                                               have nt got my card
# 95     41                                                  was to be mailed
# 94    120                                      has not come in the mail yet
# 93    114                                       have n't gotten my new card
# 92     11            have n't received my card after two weeks , is it lost
# 91     46                                                              lost
# 88    125                                                         gets here
# 87    106                                      has n't came in the mail yet
# 84     84                                     ordered my new card last week
# 83    113           'm still waiting for my card that was issued a week ago
# 57     85                                                          's go on
# 79    152                                                           arrived
# 77     76                                              has n't shown up yet
# 58     62                                                   has n't arrived
# 50     10                                                              come
# 56     71                  's the expected wait time to recieve my new card
# 20     56                                    take for me to get my new card
# 29     51                                         can get my card expedited
# 28     91                                      'm still waiting for my card
# 26    137                                  was issued a new card a week ago
# 25     98          would like to track a card sent to me , how do I do that
# 24     37                              's the tracking on the card you sent
# 23     80                                               has n't arrived yet
# 22    136                               is the tracking number for the card
# 21      8                                                     have tracking
# 19    119                                       take to recieve my new card
# 55     61                                      am still waiting for my card
# 16     33                                                   has n't came in
# 14    104                                          received my new card yet
# 10     86                                          have n't received it yet
# 8     112                             have n't received my card in the mail
# 7     101                                         have not received my card
# 5       7                       do if I still have not received my new card
# 4      24                                                    is my new card
# 3     105                          is the expected delivery date of my card
# 30     16               do n't have my card in 1 week . Should I be worried
# 32    102                              can check on the card on route to me
# 33     92  need to do to get my new card which I have requested 2 weeks ago
# 34     22                                              sent out my card yet
# 54    124           thought I would have received my new card at this point
# 53    147                                  going to take to get my new card
# 52    121                                        sent me 's tracking number
# 51     96                                                    be here by now
# 1     135                                  was expecting my new card by now
# 48    134                   's been two weeks and I have n't gotten my card
# 47      2          have been waiting over a week . Is the card still coming
# 46     73                                            was supposed to arrive
# 45    150                        has n't arrived after two weeks , now what
# 44     30                                                           sent me
# 42     18          has not been delivered to my home yet . What is going on
# 41     45                                  'm still waiting for my new card
# 40    151                                     appears to have never arrived
# 39    149                                               has n't arrived yet
# 38     27                                               recieve my new card
# 36     97                                                   has n't arrived
# 35     66                have to wait much longer for my new card to arrive
# 99    141                   'm still waiting on my new card to be delivered
#
#    annots  \
# 0     yes
# 17    yes
# 75    yes
# 71    yes
# 78    yes
# 70    yes
# 31    yes
# 80    yes
# 81    yes
# 43    yes
# 27    yes
# 69    yes
# 85    yes
# 86    yes
# 89    yes
# 18    yes
# 90    yes
# 65    yes
# 11    yes
# 2     yes
# 60    yes
# 6     yes
# 9     yes
# 15    yes
# 37    yes
# 12    yes
# 13    yes
# 49    yes
# 68     no
# 67     no
# 63     no
# 62     no
# 66     no
# 61     no
# 59     no
# 72     no
# 73     no
# 64     no
# 82     no
# 74     no
# 76     no
# 98     no
# 97     no
# 96     no
# 95     no
# 94     no
# 93     no
# 92     no
# 91     no
# 88     no
# 87     no
# 84     no
# 83     no
# 57     no
# 79     no
# 77     no
# 58     no
# 50     no
# 56     no
# 20     no
# 29     no
# 28     no
# 26     no
# 25     no
# 24     no
# 23     no
# 22     no
# 21     no
# 19     no
# 55     no
# 16     no
# 14     no
# 10     no
# 8      no
# 7      no
# 5      no
# 4      no
# 3      no
# 30     no
# 32     no
# 33     no
# 34     no
# 54     no
# 53     no
# 52     no
# 51     no
# 1      no
# 48     no
# 47     no
# 46     no
# 45     no
# 44     no
# 42     no
# 41     no
# 40     no
# 39     no
# 38     no
# 36     no
# 35     no
# 99     no
#
#                                                                                                    text  \
# 0                                                                  How do I track the card you sent me?
# 17                                   Can you please tell me where my card is? I ordered it 2 weeks ago!
# 75                                                Will I be able to track the card that was sent to me?
# 71                                                     Is there a way to track the delivery of my card?
# 78                                          Can I track my card while it is in the process of delivery?
# 70                                                          Can I track when my card will be delivered?
# 31                                                             How much longer until I get my new card?
# 80                                                    Is there a way to track the new card you sent me?
# 81                                                         Do you have info about the card on delivery?
# 43                                                     I want to find out what happened to my new card?
# 27                                                     Was there a way for me to get tracking for that?
# 69                                                        How can I check on the status of my new card?
# 85                                                                  can you share card tracking number?
# 86                                                                        Can you track my card for me?
# 89                                         Is it possible for me to track the card is was mailed to me?
# 18                                                   How can I check on the delivery status of my card?
# 90                                                                        how can i track card you sent
# 65                                                                     Is there a way to track my card?
# 11                                                                    Could I get tracking on the card?
# 2                                                                  Can I track the card you sent to me?
# 60                                                        Is it possible to track the card you sent me?
# 6                                                   Can you tell me why I haven't received my new card?
# 9                                       How can I periodically check the delivery of the card you sent?
# 15                                                 I need to find out where the card is that I ordered.
# 37                                                   Can I track the card that you sent me in the mail?
# 12                                                       Can I track the card that was just sent to me?
# 13                                                 Can you tell me if I can track the card you sent me?
# 49                                                Am I able to track the card that was just sent to me?
# 68                                                                       Can you help me track my card?
# 67                                                                 WHAT IS THE SOLUTION OF THIS PROBLEM
# 63                                                                          I haven't received my card.
# 62                                     I was issued a card about a week ago. why hasn't it come in yet?
# 66                                                                        I haven't gotten my new card.
# 61                                      Is a tracking number available for the card that was just sent?
# 59                   My card hasn't arrived in the mail yet. I ordered it two weeks ago. What can I do?
# 72                                                                      why have i not got my new card?
# 73                                                            How long will it be to get this new card?
# 64                                                       A card has been sent to me, how do I track it?
# 82                                2 weeks ago I ordered my new card.  It isn't here.  What should I do?
# 74                                                On the card that is coming, what's the tracking info?
# 76                                                         What can I do to track the card you sent me?
# 98                                             Could you send me and up date on the arrival of my card?
# 97                                         What can I do if my card still hasn't arrived after 2 weeks?
# 96                                                                                 i havent got my card
# 95                                                       Where is my credit card that was to be mailed?
# 94                                                                My card has not come in the mail yet.
# 93                                          I still haven't gotten my new card.  When will it get here?
# 92                                        I still haven't received my card after two weeks, is it lost?
# 91                                          Is my card lost? I am still waiting for it to be delivered.
# 88                                                                How long until my new card gets here?
# 87                                                                 My card hasn't came in the mail yet?
# 84                     If I ordered my new card last week, how much longer should I wait to receive it?
# 83                          I'm still waiting for my card that was issued a week ago. What should I do?
# 57                                                                  What's go on, where is my new card?
# 79                                                                               My card never arrived.
# 77                                                                         My card hasn't shown up yet.
# 58                                                                              My card hasn't arrived.
# 50                                                                  Why has my new card still not come?
# 56                                                What's the expected wait time to recieve my new card?
# 20                                                     How long does it take for me to get my new card?
# 29                                                          Is there a way I can get my card expedited?
# 28                                                                       I'm still waiting for my card.
# 26  I was issued a new card a week ago but still haven't received it. How long will it be until I re...
# 25                                           I would like to track a card sent to me, how do I do that?
# 24                                                            What's the tracking on the card you sent?
# 23                                                    Is there a reason my new card hasn't arrived yet?
# 22                                                           Where is the tracking number for the card?
# 21                                                         Does the package with my card have tracking?
# 19                                                        How long does it take to recieve my new card?
# 55                                                                      I am still waiting for my card.
# 16                                                                          My new card hasn't came in.
# 14                                                              Why haven't I received my new card yet?
# 10                                                   Where is my new card if I haven't received it yet?
# 8                                                          I still haven't received my card in the mail
# 7                                       I have not received my card and it's been a week, what do I do?
# 5                                                What do I do if I still have not received my new card?
# 4                                                                                 where is my new card?
# 3                                                        What is the expected delivery date of my card?
# 30                                                I don't have my card in 1 week.  Should I be worried?
# 32                                               Is there a way I can check on the card on route to me?
# 33                          What do I need to do to get my new card which I have requested 2 weeks ago?
# 34                                                                       Have you sent out my card yet?
# 54                                           I thought I would have received my new card at this point.
# 53                                              How much longer is it going to take to get my new card?
# 52                                                       What's the card you sent me's tracking number?
# 51                                                                Shouldn't my new card be here by now?
# 1                                                                   I was expecting my new card by now.
# 48                                      It's been two weeks and I haven't gotten my card, what do I do?
# 47                                           I have been waiting over a week. Is the card still coming?
# 46                                                          My card was supposed to arrive, but hasn't?
# 45                                              My card still hasn't arrived after two weeks, now what?
# 44                                                 Is there a tracking number for the card you sent me?
# 42                                 My new card has not been delivered to my home yet. What is going on?
# 41                                                                   I'm still waiting for my new card.
# 40                                                               My card appears to have never arrived?
# 39                                                            My card hasn't arrived yet. What do I do?
# 38                                                                     When will I recieve my new card?
# 36                                                        Is there a reason my new card hasn't arrived?
# 35                                           Will I have to wait much longer for my new card to arrive?
# 99                                                    I'm still waiting on my new card to be delivered!
#
#                          cfg
# 0                VP -> VB NP
# 17  VP -> VB NP SBAR . NP VP
# 75             VP -> VB ADJP
# 71               VP -> TO VP
# 78          VP -> VB NP SBAR
# 70             VP -> VB SBAR
# 31              VP -> VBP NP
# 80               VP -> TO VP
# 81               VP -> VB NP
# 43               VP -> VBP S
# 27               VP -> TO VP
# 69               VP -> VB PP
# 85               VP -> VB NP
# 86            VP -> VB NP PP
# 89               VP -> TO VP
# 18               VP -> VB PP
# 90         VP -> VB NP NP VP
# 65               VP -> TO VP
# 11               VP -> VB NP
# 2                VP -> VB NP
# 60               VP -> TO VP
# 6           VP -> VB NP SBAR
# 9                VP -> VB NP
# 15               VP -> VBP S
# 37               VP -> VB NP
# 12               VP -> VB NP
# 13          VP -> VB NP SBAR
# 49               VP -> TO VP
# 68                VP -> VB S
# 67              VP -> VBZ NP
# 63           VP -> VBP RB VP
# 62              VP -> VBD VP
# 66           VP -> VBP RB VP
# 61         VP -> VBD ADVP VP
# 59           VP -> VBZ RB VP
# 72              VP -> VBN NP
# 73                VP -> VB S
# 64              VP -> VBZ VP
# 82              VP -> VBD NP
# 74              VP -> VBZ VP
# 76                VP -> VB S
# 98   VP -> VB NP CC IN NP PP
# 97             VP -> VB SBAR
# 96           VP -> VBP RB VP
# 95               VP -> VBD S
# 94           VP -> VBZ RB VP
# 93           VP -> VBP RB VP
# 92             VP -> VP , SQ
# 91                 VP -> VBN
# 88            VP -> VBZ ADVP
# 87           VP -> VBZ RB VP
# 84           VP -> VBD NP NP
# 83         VP -> VBP ADVP VP
# 57              VP -> VBZ VP
# 79                 VP -> VBD
# 77           VP -> VBZ RB VP
# 58           VP -> VBZ RB VP
# 50                 VP -> VBN
# 56              VP -> VBZ NP
# 20             VP -> VB SBAR
# 29               VP -> MD VP
# 28         VP -> VBP ADVP VP
# 26              VP -> VBD VP
# 25               VP -> MD VP
# 24              VP -> VBZ NP
# 23           VP -> VBZ RB VP
# 22              VP -> VBZ NP
# 21              VP -> VBP NP
# 19                VP -> VB S
# 55         VP -> VBP ADVP VP
# 16           VP -> VBZ RB VP
# 14         VP -> VBD NP ADVP
# 10           VP -> VBP RB VP
# 8            VP -> VBP RB VP
# 7            VP -> VBP RB VP
# 5              VP -> VB SBAR
# 4               VP -> VBZ NP
# 3               VP -> VBZ NP
# 30             VP -> VP . SQ
# 32               VP -> MD VP
# 33                VP -> VB S
# 34     VP -> VBN PRT NP ADVP
# 54            VP -> VBD SBAR
# 53               VP -> VBG S
# 52              VP -> VBD NP
# 51          VP -> VB ADVP PP
# 1               VP -> VBD VP
# 48         VP -> VBZ VP CC S
# 47              VP -> VBP VP
# 46              VP -> VBD VP
# 45           VP -> VBZ RB VP
# 44              VP -> VBD NP
# 42           VP -> VP . SBAR
# 41         VP -> VBP ADVP VP
# 40               VP -> VBZ S
# 39           VP -> VBZ RB VP
# 38               VP -> VB NP
# 36           VP -> VBZ RB VP
# 35                VP -> VB S
# 99         VP -> VBP ADVP VP

# %% [markdown]
#  **Fig. Only 16% of intents are well formed.**

# %%
n_total = len(sorted_annots)
n_null = sorted_annots['annots'].isnull().sum()
n_yes = sorted_annots['annots'].eq('yes').sum()
n_no = sorted_annots['annots'].eq('no').sum()
stats = pd.DataFrame({
    'annots': ['null', 'yes', 'no','Total'], 
    'count': [n_null, n_yes, n_no, n_total],
    '%': [n_null/n_total*100, n_yes/n_total*100, n_no/n_total*100, 100]
    })
stats
# Out:
#   annots  count      %
# 0   null      0    0.0
# 1    yes     28   28.0
# 2     no     72   72.0
# 3  Total    100  100.0

# %% [markdown]
#  2. Can we detect intent VPs automatically in task-oriented queries?
#    2.1. How do "intent" VPs differ from non-intent "VPs"?
#        2.1.1 Candidate hypotheses:
#            - sentence mood: declarative vs. interrogative syntax
#            - tense: present vs. past ?
#            - lexical: some verbs and not others
#            - dependency structure: direct object vs. indirect ?
#
#  Observations:
#    1.1 Grammar features of the VPs that we labelled as intents:
#        - intent -> VB_present + NP
#        - intent -> VB_present + VB_present + NP
#        - intent -> VB_infinitive + NP
#        - intent -> VB_present + clause
#
#    1.2 Grammar features of VPs that we did not label as intents:
#        1.2.1. Implicit, intents at the level of semantics/pragmatics:
#        - failed intent -> gerund VB | auxiliary VB | past tense VB | interrogative phrase
#
#        1.2.2. Grammar features of intents that we are not exploiting:
#        - intent -> need | want + VB_infinitive

# %% [markdown]
# ### Parse well-formed intent's intent and entities (slot analysis)
#
#  We formalized an intent as follows:
#
#    e.g., : "track my card for me"
#
#    intent -> VB + NP
#        entity: PP
#
#  POS terminology
#    - SBAR: Subordinate Clause (e.g., after ..)

# %% [markdown]
#  CFG FEATURES

# %%
sorted_annots.head()
# Out:
#     index                                                    VP annots  \
# 0      26                            track the card you sent me    yes
# 17    111   tell me where my card is ? I ordered it 2 weeks ago    yes
# 75     15         be able to track the card that was sent to me    yes
# 71     13                      to track the delivery of my card    yes
# 78      3  track my card while it is in the process of delivery    yes
#
#                                                                   text  \
# 0                                 How do I track the card you sent me?
# 17  Can you please tell me where my card is? I ordered it 2 weeks ago!
# 75               Will I be able to track the card that was sent to me?
# 71                    Is there a way to track the delivery of my card?
# 78         Can I track my card while it is in the process of delivery?
#
#                          cfg
# 0                VP -> VB NP
# 17  VP -> VB NP SBAR . NP VP
# 75             VP -> VB ADJP
# 71               VP -> TO VP
# 78          VP -> VB NP SBAR

# %%
# jupyter nbconvert --no-input --to=pdf 2_Intent_parsing.ipynb
