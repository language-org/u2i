# %% [markdown]
# # INTENT PARSING

# %% [markdown]
# * **Purpose** :
#   * Test intent parsing with ALLENLP

# %% [markdown]
#  * TABLE OF CONTENT
#  * SETUP
#    * paths
#  * PARAMETERS
#  * PARSING
#    * Allennlp VP parsing
#    * Parsing performance
#    * Focus on the class well parsed
#  * ANNOTATION

# %% [markdown]
# # SETUP

# %%
import os
from datetime import datetime
from time import time

import numpy as np
import pandas as pd
import yaml
from nltk.tree import ParentedTree
from pigeon import annotate

proj_path = "/Users/steeve_laquitaine/desktop/CodeHub/intent/"
os.chdir(proj_path)
# in root
from intent.src.intent.nodes import mood, parsing

# dataframe display
pd.set_option("display.max_colwidth", 100)
pd.set_option("display.max_rows", 1000)

# pd.set_option('display.notebook_repr_html', True)

# to display df w/ nbconvert to pdf
# def _repr_latex_(self):
    # return "\centering{%s}" % self.to_latex()
# pd.DataFrame._repr_latex_ = _repr_latex_  # monkey patch pandas DataFrame

# %% [markdown]
# ## paths

# %%
# load catalog
with open(proj_path+"intent/conf/base/catalog.yml") as file:
    catalog = yaml.load(file)
with open(proj_path+"intent/conf/base/parameters.yml") as file:
    prms = yaml.load(file)
tr_data_path = proj_path + "intent/data/01_raw/banking77/train.csv"
test_data_path = proj_path + "intent/data/01_raw/banking77/test.csv"

# %% [markdown]
# # PARAMETERS

# %%
prm = dict()
prm["sample"] = 100
prm["mood"] = ["declarative"]
prm["intent_class"] = "card_arrival"  # good parsing performance

# %%
# read queries data
tr_data = pd.read_csv(tr_data_path)

# %%
# select data for an input class
data = tr_data[tr_data["category"].eq(prm["intent_class"])]

# %%
data.head(5)
# Out:
#                                                            text      category
# 0                                I am still waiting on my card?  card_arrival
# 1  What can I do if my card still hasn't arrived after 2 weeks?  card_arrival
# 2    I have been waiting over a week. Is the card still coming?  card_arrival
# 3   Can I track my card while it is in the process of delivery?  card_arrival
# 4        How do I know if I will get my card, or if it is lost?  card_arrival

# %%
sample = data["text"].iloc[0]

# %% [markdown]
# # PARSING

# %% [markdown]
# ## ALLENLP VP PARSING

# %%
tic = time()
al_prdctor = parsing.init_allen_parser()
print(f"(Instantiation) took {round(time()-tic,2)} secs")
# Out:
# (Instantiation) took 30.8 secs

# %%
tic = time()
output = al_prdctor.predict(sentence=sample)
parsed_txt = output["trees"]
print(f"(Inference) took {round(time()-tic,2)} secs")
print(f"Parsed sample:\n{parsed_txt}")
# Out:
# (Inference) took 0.3 secs
# Parsed sample:
# (S (NP (PRP I)) (VP (VBP am) (ADVP (RB still)) (VP (VBG waiting) (PP (IN on) (NP (PRP$ my) (NN card))))) (. ?))

# %%
tree = ParentedTree.fromstring(parsed_txt)
assert len(parsing.extract_VP(al_prdctor, "I want coffee")) > 0, "VP is Empty"

# %%
# Speed up (1 hour / 10K queries)
VPs = parsing.extract_all_VPs(prm, data, al_prdctor)
assert (
    len(VPs) == len(data) or len(VPs) == prm["sample"]
), '''VP's length does not match "data"'''
# Out:
# Time to completion: 79.28
# Time to completion: 60.47
# Time to completion: 51.51
# Time to completion: 51.73
# Time to completion: 47.52
# Time to completion: 46.61
# Time to completion: 49.31
# Time to completion: 46.95
# Time to completion: 49.87
# Time to completion: 48.46
# Time to completion: 46.92
# 38.02

# %%
# augment dataset with VPs
data["VP"] = pd.DataFrame(VPs)
data.iloc[: prm["sample"]]
# Out:
#                                                                                                    text  \
# 0                                                                        I am still waiting on my card?
# 1                                          What can I do if my card still hasn't arrived after 2 weeks?
# 2                                            I have been waiting over a week. Is the card still coming?
# 3                                           Can I track my card while it is in the process of delivery?
# 4                                                How do I know if I will get my card, or if it is lost?
# 5                                                                     When did you send me my new card?
# 6                                                          Do you have info about the card on delivery?
# 7                                                What do I do if I still have not received my new card?
# 8                                                          Does the package with my card have tracking?
# 9                                                             I ordered my card but it still isn't here
# 10                                                                  Why has my new card still not come?
# 11                                        I still haven't received my card after two weeks, is it lost?
# 12                                                                        Can you track my card for me?
# 13                                                     Is there a way to track the delivery of my card?
# 14                             It's been a week since I ordered my card and it's not here. Please help?
# 15                                                Will I be able to track the card that was sent to me?
# 16                                                I don't have my card in 1 week.  Should I be worried?
# 17                                                   How do I know when my new card is going to arrive?
# 18                                 My new card has not been delivered to my home yet. What is going on?
# 19        It's been a week since you issued me a card and I still didn't get it. Should I keep waiting?
# 20                                                On the card that is coming, what's the tracking info?
# 21                                                            What is the status of my card's delivery?
# 22                                                                       Have you sent out my card yet?
# 23                                                                              My card isn't here yet.
# 24                                                                                where is my new card?
# 25                                   It's been a week since you sent my card and I still don't have it.
# 26                                                                 How do I track the card you sent me?
# 27                                                                     When will I recieve my new card?
# 28                                                                         When will I get my new card?
# 29                                                      What is the expected delivery date for my card?
# 30                                                 Is there a tracking number for the card you sent me?
# 31                                                       I would like to track the card you sent to me.
# 32                                                                   Has my card been lost in delivery?
# 33                                                                          My new card hasn't came in.
# 34                                                             Where is the card I ordered 2 weeks ago?
# 35                                                          Can I get an update on my replacement card?
# 36                                                        How long does it take for a new card to ship?
# 37                                                            What's the tracking on the card you sent?
# 38                                                I haven't received my card and am worried it is lost.
# 39                                                                  My card still hasn't been delivered
# 40                                                 I need to find out where the card is that I ordered.
# 41                                                       Where is my credit card that was to be mailed?
# 42                                                   I ordered my card but it hasn't been delivered yet
# 43                                                Am I able to track the card that was just sent to me?
# 44                                                  Can you tell me why I haven't received my new card?
# 45                                                                   I'm still waiting for my new card.
# 46                                          Is my card lost? I am still waiting for it to be delivered.
# 47                                                   Should I keep waiting for my card to be delivered?
# 48                                                          Can I track when my card will be delivered?
# 49                                                        How can I check on the status of my new card?
# 50                                                       A card has been sent to me, how do I track it?
# 51                                                          Is there a way I can get my card expedited?
# 52                                                         What can I do to track the card you sent me?
# 53                                                                       why hasnt my card come in yet?
# 54                                      How can I periodically check the delivery of the card you sent?
# 55                                                           What's the reason my new card hasn't come?
# 56                                                     How long does it take for me to get my new card?
# 57                                           I don't have my card after 1 week. What are my next steps?
# 58                   I know I'm getting a new card but would like know when I can expect to receive it.
# 59                                                     I want to find out what happened to my new card?
# 60                                                     Was there a way for me to get tracking for that?
# 61                                                                      I am still waiting for my card.
# 62                                                                              My card hasn't arrived.
# 63                                                                 Can I track the card you sent to me?
# 64                                                                        I haven't gotten my new card.
# 65  How long should it take for my new card to arrive in them mail? What should I do if I never rece...
# 66                                           Will I have to wait much longer for my new card to arrive?
# 67                                                                       how to track the card you sent
# 68                                2 weeks ago I ordered my new card.  It isn't here.  What should I do?
# 69                                                   How can I check on the delivery status of my card?
# 70               My card has not been delivered yet and its been a week since I ordered it, please help
# 71                                                What's the expected wait time to recieve my new card?
# 72                                    How can I see the progress of delivery of the card that was sent?
# 73                                                          My card was supposed to arrive, but hasn't?
# 74                    I ordered a card and would like to know how to track the delivery progress of it.
# 75                                                         How long will it take for me to get my card?
# 76                                                                         My card hasn't shown up yet.
# 77                                                       Does the card you sent have a tracking number?
# 78                   My card hasn't arrived in the mail yet. I ordered it two weeks ago. What can I do?
# 79                                                               maximum how many days get the courier?
# 80                                                    Is there a reason my new card hasn't arrived yet?
# 81                   I've been waiting a while for my card, is there a way to know when it will arrive?
# 82                                                                  How can I track my card's delivery?
# 83                                                       Can I track the card that was just sent to me?
# 84                     If I ordered my new card last week, how much longer should I wait to receive it?
# 85                                                                  What's go on, where is my new card?
# 86                                                   Where is my new card if I haven't received it yet?
# 87                                                                                    Where is my card?
# 88                                              Can you tell me why I haven't received my new card yet?
# 89                                                                     Is there a way to track my card?
# 90                                                    Is there a way to track the new card you sent me?
# 91                                                                       I'm still waiting for my card.
# 92                          What do I need to do to get my new card which I have requested 2 weeks ago?
# 93                                                                 WHAT IS THE SOLUTION OF THIS PROBLEM
# 94                                                                    Could I get tracking on the card?
# 95                                                                       Can you help me track my card?
# 96                                                                Shouldn't my new card be here by now?
# 97                                                        Is there a reason my new card hasn't arrived?
# 98                                           I would like to track a card sent to me, how do I do that?
# 99                                                             Is there a tracking number for the card?
#
#         category  \
# 0   card_arrival
# 1   card_arrival
# 2   card_arrival
# 3   card_arrival
# 4   card_arrival
# 5   card_arrival
# 6   card_arrival
# 7   card_arrival
# 8   card_arrival
# 9   card_arrival
# 10  card_arrival
# 11  card_arrival
# 12  card_arrival
# 13  card_arrival
# 14  card_arrival
# 15  card_arrival
# 16  card_arrival
# 17  card_arrival
# 18  card_arrival
# 19  card_arrival
# 20  card_arrival
# 21  card_arrival
# 22  card_arrival
# 23  card_arrival
# 24  card_arrival
# 25  card_arrival
# 26  card_arrival
# 27  card_arrival
# 28  card_arrival
# 29  card_arrival
# 30  card_arrival
# 31  card_arrival
# 32  card_arrival
# 33  card_arrival
# 34  card_arrival
# 35  card_arrival
# 36  card_arrival
# 37  card_arrival
# 38  card_arrival
# 39  card_arrival
# 40  card_arrival
# 41  card_arrival
# 42  card_arrival
# 43  card_arrival
# 44  card_arrival
# 45  card_arrival
# 46  card_arrival
# 47  card_arrival
# 48  card_arrival
# 49  card_arrival
# 50  card_arrival
# 51  card_arrival
# 52  card_arrival
# 53  card_arrival
# 54  card_arrival
# 55  card_arrival
# 56  card_arrival
# 57  card_arrival
# 58  card_arrival
# 59  card_arrival
# 60  card_arrival
# 61  card_arrival
# 62  card_arrival
# 63  card_arrival
# 64  card_arrival
# 65  card_arrival
# 66  card_arrival
# 67  card_arrival
# 68  card_arrival
# 69  card_arrival
# 70  card_arrival
# 71  card_arrival
# 72  card_arrival
# 73  card_arrival
# 74  card_arrival
# 75  card_arrival
# 76  card_arrival
# 77  card_arrival
# 78  card_arrival
# 79  card_arrival
# 80  card_arrival
# 81  card_arrival
# 82  card_arrival
# 83  card_arrival
# 84  card_arrival
# 85  card_arrival
# 86  card_arrival
# 87  card_arrival
# 88  card_arrival
# 89  card_arrival
# 90  card_arrival
# 91  card_arrival
# 92  card_arrival
# 93  card_arrival
# 94  card_arrival
# 95  card_arrival
# 96  card_arrival
# 97  card_arrival
# 98  card_arrival
# 99  card_arrival
#
#                                                                                               VP
# 0                                                    take for my new card to arrive in them mail
# 1                                                        check the delivery of the card you sent
# 2                                                           track when my card will be delivered
# 3                                            tell me where my card is ? I ordered it 2 weeks ago
# 4                                                                                      gets here
# 5                                                 have a tracking number for the card I was sent
# 6                               need to do to get my new card which I have requested 2 weeks ago
# 7                                                                          been lost in delivery
# 8   's been a week since you issued me a card and I still did n't get it . Should I keep waiting
# 9                                                                            send me my new card
# 10                                                                                          come
# 11                                                                        has n't been delivered
# 12                                                                                          lost
# 13                                                                                   is n't here
# 14                                                                      have n't received it yet
# 15                                                        's the reason my new card has n't come
# 16                ordered a card and would like to know how to track the delivery progress of it
# 17                                                                               has n't arrived
# 18                                                 want to find out what happened to my new card
# 19                                                                    take for me to get my card
# 20                                                                               is n't here yet
# 21                                                                                   arrived yet
# 22                                                 be able to track the card that was sent to me
# 23                                                              going to take to get my new card
# 24                                                   would like to track the card you sent to me
# 25                                                 send me and up date on the arrival of my card
# 26                                                            check on the status of my new card
# 27                                           do n't have my card in 1 week . Should I be worried
# 28                                                                           has n't arrived yet
# 29                                      has not been delivered to my home yet . What is going on
# 30                                                                       be to get this new card
# 31                                                        's been a week since I ordered my card
# 32                                                                                        arrive
# 33                                                                               ordered my card
# 34                                                                   have n't gotten my new card
# 35                                                                      received my new card yet
# 36                                                   do if I still have not received my new card
# 37                                                                                 was just sent
# 38                                                                                      's go on
# 39                                                                          track my card for me
# 40                                                              do to track the card you sent me
# 41                                                                                          None
# 42                                                                 appears to have never arrived
# 43                                                                     to track that I could get
# 44                                                                      get tracking on the card
# 45                                                               IS THE SOLUTION OF THIS PROBLEM
# 46                                                                   take for a new card to ship
# 47                                                                   am still waiting on my card
# 48                                                                 track the card you sent to me
# 49                                                                           ordered 2 weeks ago
# 50                                                    was supposed to receive my new card by now
# 51                                                                                be here by now
# 52                                                          get an update on my replacement card
# 53                                                      know when my new card is going to arrive
# 54                                                                    track the card you sent me
# 55                                                 know if I will get my card , or if it is lost
# 56                                                                                       arrived
# 57                                                                    to track the card you sent
# 58                                                                     have n't received my card
# 59                                                      is the expected delivery date of my card
# 60                                                                               get the courier
# 61                                                          's the tracking on the card you sent
# 62                                                                             to track the card
# 63                                                              to track the delivery of my card
# 64                                               's been two weeks and I have n't gotten my card
# 65                                     do n't have my card after 1 week . What are my next steps
# 66                                                                  has n't came in the mail yet
# 67                                                         have n't received my card in the mail
# 68                                                                           ordered my new card
# 69                                                                   take to recieve my new card
# 70                                                          've been waiting a while for my card
# 71                                                                 to track the card you sent me
# 72                                                                            gotten my new card
# 73                                                                    share card tracking number
# 74                                                   track the card that you sent me in the mail
# 75                                       'm still waiting for my card that was issued a week ago
# 76                                                                               has n't came in
# 77                                                                      was sen to me be tracked
# 78                                        have n't received my card after two weeks , is it lost
# 79                                                                          has n't shown up yet
# 80                                                      keep waiting for my card to be delivered
# 81                                                   tell me if I can track the card you sent me
# 82                                            have to wait much longer for my new card to arrive
# 83                                                                  am still waiting for my card
# 84                                                                    is there a way to track it
# 85                                                                                is my new card
# 86                                                    have n't gotten my credit card in the mail
# 87                                                                               got my new card
# 88                                                                           track card you sent
# 89                                                       check on the delivery status of my card
# 90                                                          have info about the card on delivery
# 91                                                                  'm still waiting for my card
# 92                                                       track the card that was just sent to me
# 93                                                                    sent me 's tracking number
# 94                                                                     have not received my card
# 95                                                         's been a week since you sent my card
# 96                                                                           has n't arrived yet
# 97                                                                           has been sent to me
# 98                                                              was expecting my new card by now
# 99                                             do if my card still has n't arrived after 2 weeks

# %% [markdown]
#  Write parsed data

# %%
data.to_excel(catalog['parsed'])

# %%
# verb_p[0].pretty_print()

# %% [markdown]
# ## PARSING PERFORMANCE
#
#  * **Parser works in 62% of the cases for "card_arrival" and never for other classes**
#
#    * see 2a_eda_parsing.py
#    * We will analyse why later.
#    * We now focus on the class well parsed: "card_arrival".

# %% [markdown]
# ## FOCUS ON THE CLASS WELL PARSED
#
#  moods = mood.classify_sentence_type(data["text"])
#  moods
#
# ### ANNOTATE
#
#  1. Annotate VPs that look like intent vs. not
#  2. Look what make them different
#  3. Test a few hypothesis:
#    - mood: declarative vs. interrogative syntax ?
#    - tense: present vs. past ?
#    - lexical: some verbs and not others
#    - else ?
#    - semantics: direct object vs. indirect ?

# %%
annots = []
filepath = os.path.splitext(catalog['annots'])
myfile, myext = filepath[0], filepath[1]
if prms['annotation']=='do':
    annots = annotate(data["VP"], options=["yes", "no"])
elif prms['annotation'] == 'load':
    annot_path = os.path.split(catalog['annots'])[0]
    files = os.listdir(annot_path); 
    files = [file for file in files if file.startswith('annots')]
    latest_version = annot_path + '/' + files[-1]
    annots = pd.read_excel(latest_version)    
else:
    print('WARNING: you must either "load" or "do" annotations')

# %% [markdown]
#  Write annots

# %%
if prms['annotation']=='do' and not os.path.isfile(catalog['annots']):
    # add current time to filename 
    now = datetime.now().strftime("%d/%m/%Y %H:%M:%S").replace(' ','_').replace(':','_').replace('/','_')    
    annots_df = pd.DataFrame(annots)
    annots_df.to_excel(f'{myfile}_{now}{myext}')
else:
    print('WARNING: Annots was not written. To write, delete existing and rerun.')
# Out:
# WARNING: Annots was not written. To write, delete existing and rerun.

# %%
annots_df = annots.rename(columns={0:'text',1:'annot'})
annots_df['annot'][annots_df['text'].isnull()] = np.nan

# %% [markdown]
#  **Fig. Queries are sorted by annotation result below.**

# %%
annots_df = annots_df.sort_values(by='annot', ascending=False)

# %%
annots_df
# Out:
#      Unnamed: 0  \
# 78           78
# 40           40
# 22           22
# 23           23
# 25           25
# 77           77
# 73           73
# 70           70
# 43           43
# 86           86
# 64           64
# 47           47
# 48           48
# 49           49
# 54           54
# 55           55
# 82           82
# 56           56
# 89           89
# 16           16
# 97           97
# 14           14
# 91           91
# 7             7
# 90           90
# 92           92
# 94           94
# 65           65
# 93           93
# 63           63
# 62           62
# 85           85
# 95           95
# 96           96
# 61           61
# 60           60
# 59           59
# 58           58
# 98           98
# 66           66
# 69           69
# 67           67
# 68           68
# 84           84
# 71           71
# 72           72
# 74           74
# 75           75
# 76           76
# 57           57
# 79           79
# 80           80
# 88           88
# 81           81
# 87           87
# 83           83
# 0             0
# 50           50
# 53           53
# 12           12
# 24           24
# 21           21
# 20           20
# 19           19
# 18           18
# 17           17
# 15           15
# 13           13
# 11           11
# 52           52
# 10           10
# 9             9
# 8             8
# 6             6
# 5             5
# 4             4
# 3             3
# 2             2
# 26           26
# 27           27
# 28           28
# 29           29
# 51           51
# 1             1
# 46           46
# 45           45
# 44           44
# 42           42
# 41           41
# 39           39
# 38           38
# 37           37
# 36           36
# 35           35
# 34           34
# 33           33
# 32           32
# 31           31
# 30           30
# 99           99
# 100         100
# 101         101
# 102         102
# 103         103
# 104         104
# 105         105
# 106         106
# 107         107
# 108         108
# 109         109
# 110         110
# 111         111
# 112         112
# 113         113
# 114         114
# 115         115
# 116         116
# 117         117
# 118         118
# 119         119
# 120         120
# 121         121
# 122         122
# 123         123
# 124         124
# 125         125
# 126         126
# 127         127
# 128         128
# 129         129
# 130         130
# 131         131
# 132         132
# 133         133
# 134         134
# 135         135
# 136         136
# 137         137
# 138         138
# 139         139
# 140         140
# 141         141
# 142         142
# 143         143
# 144         144
# 145         145
# 146         146
# 147         147
# 148         148
# 149         149
# 150         150
# 151         151
# 152         152
#
#                                                                                              text  \
# 78                                                                          help me track my card
# 40                                                       know when my new card is going to arrive
# 22                                                                           track my card for me
# 23                                                     to track the card that was just sent to me
# 25                                                  know if I will get my card , or if it is lost
# 77                                                                               to track my card
# 73                                                                                get my new card
# 70                                            tell me where my card is ? I ordered it 2 weeks ago
# 43                                                  want to find out what happened to my new card
# 86                                                                     to track the card you sent
# 64                                           track my card while it is in the process of delivery
# 47                                                              need to track the card sent to me
# 48                                                        track the card that was just sent to me
# 49                                                              to track the new card you sent me
# 54                                                                     sent me 's tracking number
# 55                                                                                get my new card
# 82                                                                  track the card you sent to me
# 56                                                     to track a card that has already been sent
# 89                                                  send me and up date on the arrival of my card
# 16                                                                      track my card 's delivery
# 97                                                    would like to track the card you sent to me
# 14                                                                              to track the card
# 91                                                                                   be delivered
# 7                                                         check on the delivery status of my card
# 90                                                        check the delivery of the card you sent
# 92                                                                     share card tracking number
# 94                                                                                  have tracking
# 65                                                                    am still waiting on my card
# 93                                            have n't received my card and am worried it is lost
# 63                                                                                           sent
# 62                                                                            has been sent to me
# 85                                                                   has not come in the mail yet
# 95                                                                       received my new card yet
# 96                                                                 take for me to get my new card
# 61                                                                                           come
# 60                                                                   am still waiting for my card
# 59                                                                     has not been delivered yet
# 58                                                                           sent out my card yet
# 98                                                               going to take to get my new card
# 66                                                       is the expected delivery date of my card
# 69                                                                   'm still waiting for my card
# 67                                                                                has n't arrived
# 68                                                                            ordered 2 weeks ago
# 84                                                                                    is n't here
# 71                                                           can check on the card on route to me
# 72                                                                                has n't came in
# 74                                                tell me why I have n't received my new card yet
# 75                                                      is the expected delivery date for my card
# 76                                                                       was sen to me be tracked
# 57                                                     was supposed to receive my new card by now
# 79                                                           is the status of my card 's delivery
# 80                                                                                        arrived
# 88                                            do n't have my card in 1 week . Should I be worried
# 81                                                'm still waiting on my new card to be delivered
# 87   's been a week since you issued me a card and I still did n't get it . Should I keep waiting
# 83                                                                                       's go on
# 0                                         'm still waiting for my card that was issued a week ago
# 50                                                                                        sent me
# 53                                                                    have n't gotten my new card
# 12                                                    take for my new card to arrive in them mail
# 24                 ordered a card and would like to know how to track the delivery progress of it
# 21                                                                       to get tracking for that
# 20                                                                                         arrive
# 19                                        thought I would have received my new card at this point
# 18                                                                                ordered my card
# 17                                                                     take for me to get my card
# 15                                                                                    arrived yet
# 13                                                               'm still waiting for my new card
# 11                                                                                has n't arrived
# 52                                                           's the tracking on the card you sent
# 10                                                                            has n't arrived yet
# 9                                                        keep waiting for my card to be delivered
# 8                                                                                 get the courier
# 6                                                           have n't received my card in the mail
# 5                                              have to wait much longer for my new card to arrive
# 4                                                                                  be here by now
# 3                                                           's been a week since you sent my card
# 2                                                          's been a week since I ordered my card
# 26                                                                                      gets here
# 27                                                                         has n't been delivered
# 28                                                                has n't arrived in the mail yet
# 29                                                 have a tracking number for the card I was sent
# 51                                                                    have n't gotten my new card
# 1                                                     tell me why I have n't received my new card
# 46                                                's been two weeks and I have n't gotten my card
# 45                                                                            have nt got my card
# 44                                                                             gotten my new card
# 42                                                                    take for a new card to ship
# 41                                                                      have not received my card
# 39                                              need to find out where the card is that I ordered
# 38                                                                    take to recieve my new card
# 37                                                                          been lost in delivery
# 36                                                                  ordered my new card last week
# 35                                       has not been delivered to my home yet . What is going on
# 34                                      do n't have my card after 1 week . What are my next steps
# 33                                                                                is n't here yet
# 32                                              do if my card still has n't arrived after 2 weeks
# 31                                                                     is there a way to track it
# 30                                                                                 is my new card
# 99                                         have n't received my card after two weeks , is it lost
# 100                                                                                           NaN
# 101                                                                                           NaN
# 102                                                                                           NaN
# 103                                                                                           NaN
# 104                                                                                           NaN
# 105                                                                                           NaN
# 106                                                                                           NaN
# 107                                                                                           NaN
# 108                                                                                           NaN
# 109                                                                                           NaN
# 110                                                                                           NaN
# 111                                                                                           NaN
# 112                                                                                           NaN
# 113                                                                                           NaN
# 114                                                                                           NaN
# 115                                                                                           NaN
# 116                                                                                           NaN
# 117                                                                                           NaN
# 118                                                                                           NaN
# 119                                                                                           NaN
# 120                                                                                           NaN
# 121                                                                                           NaN
# 122                                                                                           NaN
# 123                                                                                           NaN
# 124                                                                                           NaN
# 125                                                                                           NaN
# 126                                                                                           NaN
# 127                                                                                           NaN
# 128                                                                                           NaN
# 129                                                                                           NaN
# 130                                                                                           NaN
# 131                                                                                           NaN
# 132                                                                                           NaN
# 133                                                                                           NaN
# 134                                                                                           NaN
# 135                                                                                           NaN
# 136                                                                                           NaN
# 137                                                                                           NaN
# 138                                                                                           NaN
# 139                                                                                           NaN
# 140                                                                                           NaN
# 141                                                                                           NaN
# 142                                                                                           NaN
# 143                                                                                           NaN
# 144                                                                                           NaN
# 145                                                                                           NaN
# 146                                                                                           NaN
# 147                                                                                           NaN
# 148                                                                                           NaN
# 149                                                                                           NaN
# 150                                                                                           NaN
# 151                                                                                           NaN
# 152                                                                                           NaN
#
#     annot
# 78    yes
# 40    yes
# 22    yes
# 23    yes
# 25    yes
# 77    yes
# 73    yes
# 70    yes
# 43    yes
# 86    yes
# 64    yes
# 47    yes
# 48    yes
# 49    yes
# 54    yes
# 55    yes
# 82    yes
# 56    yes
# 89    yes
# 16    yes
# 97    yes
# 14    yes
# 91    yes
# 7     yes
# 90    yes
# 92    yes
# 94     no
# 65     no
# 93     no
# 63     no
# 62     no
# 85     no
# 95     no
# 96     no
# 61     no
# 60     no
# 59     no
# 58     no
# 98     no
# 66     no
# 69     no
# 67     no
# 68     no
# 84     no
# 71     no
# 72     no
# 74     no
# 75     no
# 76     no
# 57     no
# 79     no
# 80     no
# 88     no
# 81     no
# 87     no
# 83     no
# 0      no
# 50     no
# 53     no
# 12     no
# 24     no
# 21     no
# 20     no
# 19     no
# 18     no
# 17     no
# 15     no
# 13     no
# 11     no
# 52     no
# 10     no
# 9      no
# 8      no
# 6      no
# 5      no
# 4      no
# 3      no
# 2      no
# 26     no
# 27     no
# 28     no
# 29     no
# 51     no
# 1      no
# 46     no
# 45     no
# 44     no
# 42     no
# 41     no
# 39     no
# 38     no
# 37     no
# 36     no
# 35     no
# 34     no
# 33     no
# 32     no
# 31     no
# 30     no
# 99     no
# 100   NaN
# 101   NaN
# 102   NaN
# 103   NaN
# 104   NaN
# 105   NaN
# 106   NaN
# 107   NaN
# 108   NaN
# 109   NaN
# 110   NaN
# 111   NaN
# 112   NaN
# 113   NaN
# 114   NaN
# 115   NaN
# 116   NaN
# 117   NaN
# 118   NaN
# 119   NaN
# 120   NaN
# 121   NaN
# 122   NaN
# 123   NaN
# 124   NaN
# 125   NaN
# 126   NaN
# 127   NaN
# 128   NaN
# 129   NaN
# 130   NaN
# 131   NaN
# 132   NaN
# 133   NaN
# 134   NaN
# 135   NaN
# 136   NaN
# 137   NaN
# 138   NaN
# 139   NaN
# 140   NaN
# 141   NaN
# 142   NaN
# 143   NaN
# 144   NaN
# 145   NaN
# 146   NaN
# 147   NaN
# 148   NaN
# 149   NaN
# 150   NaN
# 151   NaN
# 152   NaN

# %% [markdown]
#  **Fig. Proportion of "Good" intents.**

# %%
n_total = len(annots_df)
n_null = annots_df['annot'].isnull().sum()
n_yes = annots_df['annot'].eq('yes').sum()
n_no = annots_df['annot'].eq('no').sum()
stats = pd.DataFrame({
    'annot': ['null', 'yes', 'no','Total'], 
    'count': [n_yes, n_no, n_null, n_total],
    '%': [n_yes/n_total, n_no/n_total, n_null/n_total, 1]
    })
stats
# Out:
#    annot  count         %
# 0   null     26  0.169935
# 1    yes     74  0.483660
# 2     no     53  0.346405
# 3  Total    153  1.000000

# %%
# jupyter nbconvert --no-input --to=pdf 2_Intent_parsing.ipynb

# %%
n_total = len(annots_df)
n_null = annots_df['annot'].isnull().sum()
n_yes = annots_df['annot'].eq('yes').sum()
n_no = annots_df['annot'].eq('no').sum()
stats = pd.DataFrame({
    'annot': ['null', 'yes', 'no','Total'], 
    'count': [n_null, n_yes, n_no, n_total],
    '%': [n_null/n_total*100, n_yes/n_total*100, n_no/n_total*100, 100]
    })
stats
# Out:
#    annot  count           %
# 0   null     53   34.640523
# 1    yes     26   16.993464
# 2     no     74   48.366013
# 3  Total    153  100.000000
