# %% [markdown]
#  # Intent inference

# %% [markdown]
#  author: Steeve Laquitaine
#  purpose: predict intent class
#  approach:
#    - preprocessing
#        - Constituency parsing
#        - Filtering
#            - complexity: keep intents w/ N sentences
#            - mood
#            - syntax similarity
#    - inference
#        - cluster and add labels
#
#  TABLE OF CONTENTS
#
#  * Packages
#  * Parameters
#  * Load data
#  * Constituency parsing
#  * Filtering
#    * by query complexity
#    * by grammatical mood
#    * by syntactical similarity
#  * Intent parsing
#  * Label inference
#
#  Prerequisites
#
#    * cfg..xlsx
#    * sim_matrix.xlsx
#
#  Observations:
#
#    * So far the best parameters are:
#
#        SEED            = " VB NP" <br>
#        THRES_NUM_SENT  = 1 <br>
#        NUM_SENT        = 1 <br>
#        THRES_SIM_SCORE = 1 <br>
#        FILT_MOOD       = ("ask",) <br>
#
#  [TODO]:
#   - refactor and abstract pipeline
#   - link raw dataset with inference dataset with an index (primary key)

# %% [markdown]
#  # PACKAGES

# %%
# set project path
from inspect import TPFLAGS_IS_ABSTRACT
import os
from collections import defaultdict

proj_path = "/Users/steeve_laquitaine/desktop/CodeHub/intent/"
os.chdir(proj_path)

from time import time

# import packages
import pandas as pd
import spacy
import yaml
from collections import Counter
import numpy as np


# import custom nodes
from intent.src.intent.nodes import (
    features,
    inference,
    parsing,
    preprocess,
    retrieval,
    similarity,
)
from intent.src.intent.pipelines.parsing import Cfg
from intent.src.intent.pipelines.similarity import Lcs
from intent.src.tests import test_run

# shorcuts
todf = pd.DataFrame

# display
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)
pd.set_option("display.max_colwidth", None)
# Out:
# Warming up PyWSD (takes ~10 secs)... took 8.985882997512817 secs.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/steeve_laquitaine/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/steeve_laquitaine/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# /Users/steeve_laquitaine/Desktop/CodeHub/intent/intent/src/intent/nodes/preprocess.py:12: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   prms = yaml.load(file)
# /Users/steeve_laquitaine/Desktop/CodeHub/intent/intent/src/intent/nodes/parsing.py:33: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   catalog = yaml.load(file)
# /Users/steeve_laquitaine/Desktop/CodeHub/intent/intent/src/intent/pipelines/parsing.py:29: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   catalog = yaml.load(file)
# /Users/steeve_laquitaine/Desktop/CodeHub/intent/intent/src/intent/pipelines/similarity.py:23: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   catalog = yaml.load(file)

# %% [markdown]
# # PARAMETERS

# %%
SEED = " VB NP"  # seed for comparison
NUM_SENT = 1  # keep query with max one sentence
THRES_SIM_SCORE = 1  # Keep queries syntactically similar to seed
FILT_MOOD = ("ask",)  # ("state", "wish-or-excl", "ask")  # Keep statements
DIST_THRES = 5  # inference threshold for clustering, low values -> more clusters
with open(proj_path + "intent/conf/base/parameters.yml") as file:
    prms = yaml.load(file)
# Out:
# <ipython-input-2-bf4a83e76f1f>:7: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   prms = yaml.load(file)

# %% [markdown]
# # LOAD DATA

# %% [markdown]
# ## Raw data

# %%
t0 = time()
corpus_path = proj_path + "intent/data/01_raw/banking77/train.csv"
corpus = pd.read_csv(corpus_path)

# %% [markdown]
# # PREPROCESSING

# %% [markdown]
# ## Constituency parsing

# %%
# [warning] this is slow
cfg = Cfg(corpus, prms).do()
# Out:
# Your label namespace was 'pos'. We recommend you use a namespace ending with 'labels' or 'tags', so we don't add UNK and PAD tokens by default to your vocabulary.  See documentation for `non_padded_namespaces` parameter in Vocabulary.
# (Instantiation) took 31.89 secs
# Time to completion: 25.63
# Time to completion: 35.19
# Time to completion: 32.11
# Time to completion: 32.91
# Time to completion: 31.87
# Time to completion: 31.34
# Time to completion: 29.52
# Time to completion: 29.02
# Time to completion: 27.53
# Time to completion: 28.47
# Time to completion: 28.17
# 38.94
# /Users/steeve_laquitaine/Desktop/CodeHub/intent/intent/src/intent/pipelines/parsing.py:68: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   sample["VP"] = np.asarray(VPs)
# /Users/steeve_laquitaine/Desktop/CodeHub/intent/intent/src/intent/pipelines/parsing.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   annots_df["annots"][annots_df["VP"].isnull()] = np.nan

# %% [markdown]
# ## Filtering

# %% [markdown]
# ### filter complexity

# %% [markdown]
#  We kept intents with N sentences

# %%
cfg_cx = preprocess.filter_n_sent_eq(cfg, NUM_SENT, verbose=True)
# Out:
# There are 100 original queries.
# 88 after filtering = 1 sentence queries.

# %% [markdown]
# ### filter mood

# %%
cfg_mood = preprocess.filter_in_only_mood(cfg_cx, FILT_MOOD)

# %%
tag = parsing.from_cfg_to_constituents(cfg_mood["cfg"])
# Out:
# /Users/steeve_laquitaine/Desktop/CodeHub/intent/intent/src/intent/nodes/parsing.py:273: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cfg[cfg.isnull()] = ""

# %% [markdown]
# ### filter syntax similarity

# %%
# calculate similarity
similarity_matrix = Lcs().do(cfg_mood)
test_run.test_len_similarity_matx(cfg_mood, similarity_matrix)

# %%
sim_ranked = similarity.rank_nearest_to_seed(similarity_matrix, seed=SEED, verbose=True)
posting_list = retrieval.create_posting_list(tag)
ranked = similarity.print_ranked_VPs(cfg_mood, posting_list, sim_ranked)
filtered = similarity.filter_by_similarity(ranked, THRES_SIM_SCORE)
# test [TODO]
test_run.test_rank_nearest_to_seed(similarity_matrix, seed=SEED)
test_run.test_posting_list(posting_list, similarity_matrix, seed=SEED)
test_run.test_get_posting_index(cfg_mood, posting_list, sim_ranked)
# Out:
# 0 duplicated cfgs were dropped.
# 9 querie(s) is(are) left after filtering.

# %%
# map back to raw intent indices
raw_ix = cfg_mood["index"]
filtered_raw_ix = raw_ix.values[filtered.index.values]

# %% [markdown]
# ### Intent parsing

# %% [markdown]
#  1. Apply dependency parsing to each query
#  2. Apply NER
#  3. Retrieve (intent (ROOT), intendeed (dobj), entities (NER))

# %%
intents = parsing.parse_intent(filtered)

# %%
# show (intent, intendeed)
cfg_mood.index = cfg_mood["index"]
cfg_mood.merge(todf(intents, index=filtered_raw_ix), left_index=True, right_index=True)[
    ["index", "text", "intent", "intendeed"]
]
# Out:
#       index                                                           text  \
# 1375   1375                                How can I change currency type?
# 83       83                 Can I track the card that was just sent to me?
# 1432   1432                   How can I exchange currencies with this app?
# 27       27                               When will I recieve my new card?
# 1449   1449  How can I change the currency I'm exchanging from AUD to GBP?
# 63       63                           Can I track the card you sent to me?
# 1470   1470           Can this app exchange American and English currency?
# 116     116                        How do I track the card you sent to me?
# 1392   1392                                  How can I convert currencies?
#
#             intent               intendeed
# 1375        [type]                     NaN
# 83         [track]                  [card]
# 1432  [currencies]                     NaN
# 27       [recieve]                  [card]
# 1449      [change]  [currency, exchanging]
# 63         [track]                  [card]
# 1470    [currency]                     NaN
# 116        [track]                  [card]
# 1392     [convert]            [currencies]

# %% [markdown]
# # LABEL INFERENCE
#
#  1. Filter words not in Wordnet
#  2. Apply verb phrase hierarchical clustering

# %%
filtered_corpus = preprocess.filter_words(cfg_mood["VP"], "not_in_wordnet")

# %%
filtered_corpus = preprocess.drop_empty_queries(filtered_corpus)

# %%
# [warning] this is very slow
tic = time()
labels = inference.label_queries(tuple(filtered_corpus), DIST_THRES)
# Out:
# /Users/steeve_laquitaine/Desktop/CodeHub/intent/intent/src/intent/nodes/similarity.py:262: RuntimeWarning: divide by zero encountered in double_scalars
#   final_similarity = dot / tow

# %%
labels.index = filtered_corpus.index
print(f"{round(time() - tic, 2)} secs")
print(f"Total: {round(time() - t0, 2)} secs")
labelled = labels.sort_values(by=["label"])
# Out:
# 216.65 secs
# Total: 292.72 secs

# %% [markdown]
# # EVALUATION

# %% [markdown]
# ## Map cluster with True label for evaluation

# %%
true_labels = corpus.loc[labelled.index]["category"]
labelled["true_labels"] = true_labels
labelled
# Out:
#                                                    query label  \
# index
# 136                              is tracking number card     1
# 1363                                              change     1
# 44                  tell me why I have received new card     1
# 73                                   was supposed arrive     1
# 1359                             change another currency     1
# 90                                track new card sent me     1
# 1384                             change currency another     1
# 63                                    track card sent me     1
# 145                                      gotten new card     1
# 12                                         track card me     1
# 1448                                 exchange a currency     1
# 22                                     sent out card yet     1
# 5                                       send me new card     1
# 1437                                    process changing     1
# 1467                       need take exchange currencies     1
# 1449                        change currency I exchanging     1
# 126                                         get new card     1
# 109                                         be delivered     1
# 1460                         be used exchange currencies     1
# 89                                            track card     1
# 4                     know I will get card or it is lost     1
# 1392                                  convert currencies     1
# 1362                             am X but am traveling Y     1
# 134                    been two weeks I have gotten card     1
# 116                                   track card sent me     1
# 75                                      take me get card     1
# 1469                                 exchange between on     1
# 1386                       allow currencies be exchanged     1
# 150                      has arrived after two weeks now     1
# 1470                  exchange American English currency     1
# 118                      send me up date on arrival card     1
# 1433                                            exchange     1
# 1464                                            exchange     1
# 1424                                         exchange on     1
# 108                                           track card     1
# 71                           expected wait time new card     1
# 21                               is status card delivery     1
# 1380                                            use both     1
# 20                                             is coming     1
# 1440        I switch money money used in another country     1
# 55                              reason new card has come     1
# 101                               have not received card     1
# 103                                               arrive     1
# 59                       want find out happened new card     1
# 1404                  convert money different currencies     1
# 1435                                 exchange currencies     1
# 8                                          have tracking     1
# 7                  do I still have not received new card     1
# 1375                                change currency type     1
# 1408                                                need     1
# 1413                             use exchange currencies     1
# 15                        be able track card was sent me     1
# 1385                           exchange currencies using     1
# 1388                           exchange currencies using     1
# 1458                                    trade currencies     1
# 129                                      be get new card     1
# 125                                            gets here     1
# 96                                        be here by now     1
# 1457                                     tell me get not     1
# 1395                                     be exchanged on     1
# 37                                 tracking on card sent     1
# 1421                               need make an exchange     1
# 1372                                 exchange currencies     1
# 1366                                     be exchanged in     1
# 27                                              new card     1
# 1410                                            exchange     1
# 1422                 use exchange between dollars pounds     1
# 83                           track card was just sent me     1
# 1391                                              change     1
# 92     need do get new card I have requested 2 weeks ago     1
# 1474                                    use change money     1
# 1432                                 exchange currencies     1
# 1441                                  be possible change     1
# 1402                                       need exchange     1
# 97                                           has arrived     1
# 1400                                    convert currency     1
# 1364                   be exchanged one currency another     1
# 139                     tell me I can track card sent me     1
#
#             true_labels
# index
# 136        card_arrival
# 1363   exchange_via_app
# 44         card_arrival
# 73         card_arrival
# 1359   exchange_via_app
# 90         card_arrival
# 1384   exchange_via_app
# 63         card_arrival
# 145        card_arrival
# 12         card_arrival
# 1448   exchange_via_app
# 22         card_arrival
# 5          card_arrival
# 1437   exchange_via_app
# 1467   exchange_via_app
# 1449   exchange_via_app
# 126        card_arrival
# 109        card_arrival
# 1460   exchange_via_app
# 89         card_arrival
# 4          card_arrival
# 1392   exchange_via_app
# 1362   exchange_via_app
# 134        card_arrival
# 116        card_arrival
# 75         card_arrival
# 1469   exchange_via_app
# 1386   exchange_via_app
# 150        card_arrival
# 1470   exchange_via_app
# 118        card_arrival
# 1433   exchange_via_app
# 1464   exchange_via_app
# 1424   exchange_via_app
# 108        card_arrival
# 71         card_arrival
# 21         card_arrival
# 1380   exchange_via_app
# 20         card_arrival
# 1440   exchange_via_app
# 55         card_arrival
# 101        card_arrival
# 103        card_arrival
# 59         card_arrival
# 1404   exchange_via_app
# 1435   exchange_via_app
# 8          card_arrival
# 7          card_arrival
# 1375   exchange_via_app
# 1408   exchange_via_app
# 1413   exchange_via_app
# 15         card_arrival
# 1385   exchange_via_app
# 1388   exchange_via_app
# 1458   exchange_via_app
# 129        card_arrival
# 125        card_arrival
# 96         card_arrival
# 1457   exchange_via_app
# 1395   exchange_via_app
# 37         card_arrival
# 1421   exchange_via_app
# 1372   exchange_via_app
# 1366   exchange_via_app
# 27         card_arrival
# 1410   exchange_via_app
# 1422   exchange_via_app
# 83         card_arrival
# 1391   exchange_via_app
# 92         card_arrival
# 1474   exchange_via_app
# 1432   exchange_via_app
# 1441   exchange_via_app
# 1402   exchange_via_app
# 97         card_arrival
# 1400   exchange_via_app
# 1364   exchange_via_app
# 139        card_arrival

# %%
# assign the most likely label to each cluster

# %%
unique_labels = labelled["label"].unique()
predicted_labels_all = []
proba_predicted_all = []
n_labelled = len(labelled)

# for each cluster, assign its most likely true label as the predicted label
for ix, this_label in enumerate(unique_labels):

    # find indices of this cluster intents
    this_label_ix = np.where(labelled == this_label)[0]
    nb_label = len(this_label_ix)

    # find its most frequent true label
    predicted = Counter(
        labelled["true_labels"].iloc[this_label_ix].tolist()
    ).most_common()[0]

    # assign this true label as predicted label and its conditional proba
    # as proba of predicted
    predicted_labels_all += [predicted[0]] * nb_label
    proba_predicted_all += [predicted[1] / n_labelled] * nb_label
labelled["predicted"] = predicted_labels_all
labelled["proba_predicted (ratio)"] = proba_predicted_all
labelled
# Out:
#                                                    query label  \
# index
# 136                              is tracking number card     1
# 1363                                              change     1
# 44                  tell me why I have received new card     1
# 73                                   was supposed arrive     1
# 1359                             change another currency     1
# 90                                track new card sent me     1
# 1384                             change currency another     1
# 63                                    track card sent me     1
# 145                                      gotten new card     1
# 12                                         track card me     1
# 1448                                 exchange a currency     1
# 22                                     sent out card yet     1
# 5                                       send me new card     1
# 1437                                    process changing     1
# 1467                       need take exchange currencies     1
# 1449                        change currency I exchanging     1
# 126                                         get new card     1
# 109                                         be delivered     1
# 1460                         be used exchange currencies     1
# 89                                            track card     1
# 4                     know I will get card or it is lost     1
# 1392                                  convert currencies     1
# 1362                             am X but am traveling Y     1
# 134                    been two weeks I have gotten card     1
# 116                                   track card sent me     1
# 75                                      take me get card     1
# 1469                                 exchange between on     1
# 1386                       allow currencies be exchanged     1
# 150                      has arrived after two weeks now     1
# 1470                  exchange American English currency     1
# 118                      send me up date on arrival card     1
# 1433                                            exchange     1
# 1464                                            exchange     1
# 1424                                         exchange on     1
# 108                                           track card     1
# 71                           expected wait time new card     1
# 21                               is status card delivery     1
# 1380                                            use both     1
# 20                                             is coming     1
# 1440        I switch money money used in another country     1
# 55                              reason new card has come     1
# 101                               have not received card     1
# 103                                               arrive     1
# 59                       want find out happened new card     1
# 1404                  convert money different currencies     1
# 1435                                 exchange currencies     1
# 8                                          have tracking     1
# 7                  do I still have not received new card     1
# 1375                                change currency type     1
# 1408                                                need     1
# 1413                             use exchange currencies     1
# 15                        be able track card was sent me     1
# 1385                           exchange currencies using     1
# 1388                           exchange currencies using     1
# 1458                                    trade currencies     1
# 129                                      be get new card     1
# 125                                            gets here     1
# 96                                        be here by now     1
# 1457                                     tell me get not     1
# 1395                                     be exchanged on     1
# 37                                 tracking on card sent     1
# 1421                               need make an exchange     1
# 1372                                 exchange currencies     1
# 1366                                     be exchanged in     1
# 27                                              new card     1
# 1410                                            exchange     1
# 1422                 use exchange between dollars pounds     1
# 83                           track card was just sent me     1
# 1391                                              change     1
# 92     need do get new card I have requested 2 weeks ago     1
# 1474                                    use change money     1
# 1432                                 exchange currencies     1
# 1441                                  be possible change     1
# 1402                                       need exchange     1
# 97                                           has arrived     1
# 1400                                    convert currency     1
# 1364                   be exchanged one currency another     1
# 139                     tell me I can track card sent me     1
#
#             true_labels         predicted  proba_predicted (ratio)
# index
# 136        card_arrival  exchange_via_app                 0.512821
# 1363   exchange_via_app  exchange_via_app                 0.512821
# 44         card_arrival  exchange_via_app                 0.512821
# 73         card_arrival  exchange_via_app                 0.512821
# 1359   exchange_via_app  exchange_via_app                 0.512821
# 90         card_arrival  exchange_via_app                 0.512821
# 1384   exchange_via_app  exchange_via_app                 0.512821
# 63         card_arrival  exchange_via_app                 0.512821
# 145        card_arrival  exchange_via_app                 0.512821
# 12         card_arrival  exchange_via_app                 0.512821
# 1448   exchange_via_app  exchange_via_app                 0.512821
# 22         card_arrival  exchange_via_app                 0.512821
# 5          card_arrival  exchange_via_app                 0.512821
# 1437   exchange_via_app  exchange_via_app                 0.512821
# 1467   exchange_via_app  exchange_via_app                 0.512821
# 1449   exchange_via_app  exchange_via_app                 0.512821
# 126        card_arrival  exchange_via_app                 0.512821
# 109        card_arrival  exchange_via_app                 0.512821
# 1460   exchange_via_app  exchange_via_app                 0.512821
# 89         card_arrival  exchange_via_app                 0.512821
# 4          card_arrival  exchange_via_app                 0.512821
# 1392   exchange_via_app  exchange_via_app                 0.512821
# 1362   exchange_via_app  exchange_via_app                 0.512821
# 134        card_arrival  exchange_via_app                 0.512821
# 116        card_arrival  exchange_via_app                 0.512821
# 75         card_arrival  exchange_via_app                 0.512821
# 1469   exchange_via_app  exchange_via_app                 0.512821
# 1386   exchange_via_app  exchange_via_app                 0.512821
# 150        card_arrival  exchange_via_app                 0.512821
# 1470   exchange_via_app  exchange_via_app                 0.512821
# 118        card_arrival  exchange_via_app                 0.512821
# 1433   exchange_via_app  exchange_via_app                 0.512821
# 1464   exchange_via_app  exchange_via_app                 0.512821
# 1424   exchange_via_app  exchange_via_app                 0.512821
# 108        card_arrival  exchange_via_app                 0.512821
# 71         card_arrival  exchange_via_app                 0.512821
# 21         card_arrival  exchange_via_app                 0.512821
# 1380   exchange_via_app  exchange_via_app                 0.512821
# 20         card_arrival  exchange_via_app                 0.512821
# 1440   exchange_via_app  exchange_via_app                 0.512821
# 55         card_arrival  exchange_via_app                 0.512821
# 101        card_arrival  exchange_via_app                 0.512821
# 103        card_arrival  exchange_via_app                 0.512821
# 59         card_arrival  exchange_via_app                 0.512821
# 1404   exchange_via_app  exchange_via_app                 0.512821
# 1435   exchange_via_app  exchange_via_app                 0.512821
# 8          card_arrival  exchange_via_app                 0.512821
# 7          card_arrival  exchange_via_app                 0.512821
# 1375   exchange_via_app  exchange_via_app                 0.512821
# 1408   exchange_via_app  exchange_via_app                 0.512821
# 1413   exchange_via_app  exchange_via_app                 0.512821
# 15         card_arrival  exchange_via_app                 0.512821
# 1385   exchange_via_app  exchange_via_app                 0.512821
# 1388   exchange_via_app  exchange_via_app                 0.512821
# 1458   exchange_via_app  exchange_via_app                 0.512821
# 129        card_arrival  exchange_via_app                 0.512821
# 125        card_arrival  exchange_via_app                 0.512821
# 96         card_arrival  exchange_via_app                 0.512821
# 1457   exchange_via_app  exchange_via_app                 0.512821
# 1395   exchange_via_app  exchange_via_app                 0.512821
# 37         card_arrival  exchange_via_app                 0.512821
# 1421   exchange_via_app  exchange_via_app                 0.512821
# 1372   exchange_via_app  exchange_via_app                 0.512821
# 1366   exchange_via_app  exchange_via_app                 0.512821
# 27         card_arrival  exchange_via_app                 0.512821
# 1410   exchange_via_app  exchange_via_app                 0.512821
# 1422   exchange_via_app  exchange_via_app                 0.512821
# 83         card_arrival  exchange_via_app                 0.512821
# 1391   exchange_via_app  exchange_via_app                 0.512821
# 92         card_arrival  exchange_via_app                 0.512821
# 1474   exchange_via_app  exchange_via_app                 0.512821
# 1432   exchange_via_app  exchange_via_app                 0.512821
# 1441   exchange_via_app  exchange_via_app                 0.512821
# 1402   exchange_via_app  exchange_via_app                 0.512821
# 97         card_arrival  exchange_via_app                 0.512821
# 1400   exchange_via_app  exchange_via_app                 0.512821
# 1364   exchange_via_app  exchange_via_app                 0.512821
# 139        card_arrival  exchange_via_app                 0.512821

# %% [markdown]
# ## Calculate performance metrics

# %%
nb_TP = sum(labelled["predicted"] == labelled["true_labels"])
accuracy = nb_TP / n_labelled
print("Task info:")
print("- number of classes:", labelled["true_labels"].nunique())
print("\nMetrics:")
print("- accuracy:", accuracy)
# Out:
# Task info:
# - number of classes: 2
#
# Metrics:
# - accuracy: 0.5128205128205128
